# %% [markdown]
# # LAB 1: Probability Concepts, Indepdenece and Random Variables
#
# In this lab you will use python to study the following topics:
#
# - How to simulate random experiment outcomes using numpy arrays.
# - How to estimate the probability of an event using the relative frequency approach.
# - Simulate independent events.
# - Calculate arthemitic mean, sample variance, and sample standard deviation for a dataset.
# - Calculate covariance and correlation coeffecient of two random variables.

# %% [markdown]
# # First: you should run this cell

# %%
# Make all numpy available via shorter 'np' prefix
import numpy as np

# matplotlib library
import matplotlib.pyplot as plt

import pandas as pd

# %% [markdown]
# # Problem 1
#
# Use numpy to simulate the vector outcomes for repeating the following random experiments $1000$ times and use the relative frequency to compute the probability of the corresponding events:
#
# 1. **Experiment:** Flipping a fair coin, **Event:** A head occurs.
#
# Observe how changing the number of repetition affects the computed probabilities.
#
# **Hints:**
# - Use [numpy.random.randint](https://numpy.org/doc/stable/reference/random/generated/numpy.random.randint.html) or [numpy.random.choice](https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html) to simulate the experiment.
# - Other useful functions [numpy.arange](https://numpy.org/doc/stable/reference/generated/numpy.arange.html), [numpy.cumsum](https://numpy.org/doc/stable/reference/generated/numpy.cumsum.html), [numpy.sum](https://numpy.org/doc/stable/reference/generated/numpy.sum.html), and [matplotlib.pyplot.plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)

# %%
n=10
x = np.random.choice([0, 1], size=n)
print(f"n={n} , p(e) ={x.sum()/len(x)}")
n=50
x = np.random.choice([0, 1], size=n)
print(f"n={n} , p(e) ={x.sum()/len(x)}")
n=100
x = np.random.choice([0, 1], size=n)
print(f"n={n} , p(e) ={x.sum()/len(x)}")
n=500
x = np.random.choice([0, 1], size=n)
print(f"n={n} , p(e) ={x.sum()/len(x)}")
n=5000
x = np.random.choice([0, 1], size=n)
print(f"n={n} , p(e) ={x.sum()/len(x)}")
n=10000
x = np.random.choice([0, 1], size=n)
print(f"n={n} , p(e) ={x.sum()/len(x)}")
n=50000
x = np.random.choice([0, 1], size=n)
print(f"n={n} , p(e) ={x.sum()/len(x)}")
n=1000
x = np.random.choice([0, 1], size=n)
print(f"n={n} , p(e) ={x.sum()/len(x)}")
plt.axhline(y=0.5, color='r', linestyle='-')
plt.plot(np.cumsum(x)/np.arange(1,n+1));
# Out:
# n=10 , p(e) =0.4
# n=50 , p(e) =0.64
# n=100 , p(e) =0.45
# n=500 , p(e) =0.52
# n=5000 , p(e) =0.496
# n=10000 , p(e) =0.5026
# n=50000 , p(e) =0.4983
# n=1000 , p(e) =0.49

# %%
n = np.arange(0, 10000,500)
for i in range(len(n)):
  x = np.random.choice([0, 1], size=n[i])
  if i==0:
    print("n=0")
  else:
    print(f"n={n[i]} , p(e) ={x.sum()/len(x)}")
# Out:
# n=0
# n=500 , p(e) =0.52
# n=1000 , p(e) =0.535
# n=1500 , p(e) =0.5026666666666667
# n=2000 , p(e) =0.5075
# n=2500 , p(e) =0.5072
# n=3000 , p(e) =0.5006666666666667
# n=3500 , p(e) =0.49885714285714283
# n=4000 , p(e) =0.50625
# n=4500 , p(e) =0.5042222222222222
# n=5000 , p(e) =0.5138
# n=5500 , p(e) =0.502
# n=6000 , p(e) =0.49266666666666664
# n=6500 , p(e) =0.49015384615384616
# n=7000 , p(e) =0.49957142857142856
# n=7500 , p(e) =0.49906666666666666
# n=8000 , p(e) =0.500375
# n=8500 , p(e) =0.4969411764705882
# n=9000 , p(e) =0.5032222222222222
# n=9500 , p(e) =0.5030526315789474

# %%
#type your code here:
# Out:
# n = 10, P(e) = 0.6
# -----------------------------------------
# n = 50, P(e) = 0.48
# -----------------------------------------
# n = 100, P(e) = 0.52
# -----------------------------------------
# n = 500, P(e) = 0.498
# -----------------------------------------
# n = 1000, P(e) = 0.475
# -----------------------------------------
# n = 5000, P(e) = 0.4998
# -----------------------------------------
# n = 10000, P(e) = 0.5022
# -----------------------------------------
# n = 50000, P(e) = 0.5011
# -----------------------------------------
# n = 100000, P(e) = 0.49788
# -----------------------------------------

# %% [markdown]
# 2. **Experiment:** Rolling a fair die, **Event:** Number 5 occurs.

# %%
n=10000
x = np.random.choice([1,2,3,4,5,6], size=n)
p = (x==5).sum()/len(x)
print(f"n={n} , p(e) ={p}")
plt.axhline(y=1/6, color='r', linestyle='-')
plt.plot(np.cumsum(x==5)/np.arange(1,n+1));
# Out:
# n=10000 , p(e) =0.1677

# %%
n = np.arange(0, 10000,500)
for i in range(len(n)):
  x = np.random.choice([1,2,3,4,5,6], size=n[i])
  if i==0:
    print("n=0")
  else:
    p=(x==5).sum()/len(x)
    print(f"n={n[i]} , p(e) ={p}")
# Out:
# n=0
# n=500 , p(e) =0.158
# n=1000 , p(e) =0.171
# n=1500 , p(e) =0.16733333333333333
# n=2000 , p(e) =0.1695
# n=2500 , p(e) =0.164
# n=3000 , p(e) =0.169
# n=3500 , p(e) =0.17542857142857143
# n=4000 , p(e) =0.16425
# n=4500 , p(e) =0.16977777777777778
# n=5000 , p(e) =0.1636
# n=5500 , p(e) =0.17236363636363636
# n=6000 , p(e) =0.16283333333333333
# n=6500 , p(e) =0.16184615384615383
# n=7000 , p(e) =0.17085714285714285
# n=7500 , p(e) =0.17386666666666667
# n=8000 , p(e) =0.16725
# n=8500 , p(e) =0.17258823529411765
# n=9000 , p(e) =0.16555555555555557
# n=9500 , p(e) =0.168

# %%
#type your code here:
# Out:
# n = 10, P(e) = 0.2
# -----------------------------------------
# n = 50, P(e) = 0.12
# -----------------------------------------
# n = 100, P(e) = 0.19
# -----------------------------------------
# n = 500, P(e) = 0.166
# -----------------------------------------
# n = 1000, P(e) = 0.151
# -----------------------------------------
# n = 5000, P(e) = 0.1648
# -----------------------------------------
# n = 10000, P(e) = 0.1663
# -----------------------------------------
# n = 50000, P(e) = 0.1661
# -----------------------------------------
# n = 100000, P(e) = 0.16817
# -----------------------------------------

# %% [markdown]
# 3. **Experiment:** Rolling a fair die, **Event:** A number greater than 3 occurs.

# %%
n=10000
x = np.random.choice([1,2,3,4,5,6], size=n)
p = (x>3).sum()/len(x)
print(f"n={n} , p(e) ={p}")
plt.axhline(y=3/6, color='r', linestyle='-')
plt.plot(np.cumsum(x>3)/np.arange(1,n+1));
# Out:
# n=10000 , p(e) =0.4947

# %%
n = np.arange(0, 10000,500)
for i in range(len(n)):
  x = np.random.choice([1,2,3,4,5,6], size=n[i])
  if i==0:
    print("n=0")
  else:
    p=(x>3).sum()/len(x)
    print(f"n={n[i]} , p(e) ={p}")
# Out:
# n=0
# n=500 , p(e) =0.51
# n=1000 , p(e) =0.503
# n=1500 , p(e) =0.4846666666666667
# n=2000 , p(e) =0.498
# n=2500 , p(e) =0.4936
# n=3000 , p(e) =0.5046666666666667
# n=3500 , p(e) =0.5022857142857143
# n=4000 , p(e) =0.49825
# n=4500 , p(e) =0.5035555555555555
# n=5000 , p(e) =0.4968
# n=5500 , p(e) =0.5067272727272727
# n=6000 , p(e) =0.48483333333333334
# n=6500 , p(e) =0.504
# n=7000 , p(e) =0.5074285714285715
# n=7500 , p(e) =0.4962666666666667
# n=8000 , p(e) =0.502125
# n=8500 , p(e) =0.5103529411764706
# n=9000 , p(e) =0.49677777777777776
# n=9500 , p(e) =0.4943157894736842

# %%
#type your code here:
# Out:
# n = 10, P(e) = 0.6
# -----------------------------------------
# n = 50, P(e) = 0.48
# -----------------------------------------
# n = 100, P(e) = 0.44
# -----------------------------------------
# n = 500, P(e) = 0.496
# -----------------------------------------
# n = 1000, P(e) = 0.489
# -----------------------------------------
# n = 5000, P(e) = 0.5052
# -----------------------------------------
# n = 10000, P(e) = 0.4962
# -----------------------------------------
# n = 50000, P(e) = 0.49842
# -----------------------------------------
# n = 100000, P(e) = 0.49983
# -----------------------------------------

# %% [markdown]
# 4. **Experiment:** Rolling two fair dice, **Event:** Sum of two dice equal 5.

# %%
n=10000
x = np.random.choice([1,2,3,4,5,6], size=n)
y = np.random.choice([1,2,3,4,5,6], size=n)
z = x+y
p = (z==5).sum()/len(x)
print(f"n={n} , p(e) ={p}")
plt.axhline(y=4/36, color='r', linestyle='-')
plt.plot(np.cumsum(z==5)/np.arange(1,n+1));
# Out:
# n=10000 , p(e) =0.1053

# %%
n = np.arange(0, 10000,500)
for i in range(len(n)):
  x = np.random.choice([1,2,3,4,5,6], size=n[i])
  y = np.random.choice([1,2,3,4,5,6], size=n[i])
  z = x+y
  if i==0:
    print("n=0")
  else:
    p=(z==5).sum()/len(x)
    print(f"n={n[i]} , p(e) ={p}")
# Out:
# n=0
# n=500 , p(e) =0.116
# n=1000 , p(e) =0.108
# n=1500 , p(e) =0.122
# n=2000 , p(e) =0.1175
# n=2500 , p(e) =0.114
# n=3000 , p(e) =0.113
# n=3500 , p(e) =0.10628571428571429
# n=4000 , p(e) =0.11175
# n=4500 , p(e) =0.10911111111111112
# n=5000 , p(e) =0.1156
# n=5500 , p(e) =0.11254545454545455
# n=6000 , p(e) =0.11433333333333333
# n=6500 , p(e) =0.1143076923076923
# n=7000 , p(e) =0.11285714285714285
# n=7500 , p(e) =0.11186666666666667
# n=8000 , p(e) =0.1145
# n=8500 , p(e) =0.1111764705882353
# n=9000 , p(e) =0.11144444444444444
# n=9500 , p(e) =0.11147368421052632

# %%
#type your code here:
# Out:
# n = 10, P(e) = 0.1
# -----------------------------------------
# n = 50, P(e) = 0.04
# -----------------------------------------
# n = 100, P(e) = 0.11
# -----------------------------------------
# n = 500, P(e) = 0.116
# -----------------------------------------
# n = 1000, P(e) = 0.112
# -----------------------------------------
# n = 5000, P(e) = 0.1134
# -----------------------------------------
# n = 10000, P(e) = 0.1056
# -----------------------------------------
# n = 50000, P(e) = 0.10812
# -----------------------------------------
# n = 100000, P(e) = 0.10955
# -----------------------------------------

# %% [markdown]
# # Problem 2
#
# Simulate the experiment of tossing $1000$ times a coin with probability of **head (coded as $1$) equal to $0.4$** and probability of **tail (coded as $0$) equal to $0.6$**. How can you check if the simulation of the experiment of been running as expected.
#
# **Hint**: Use [matplotlib.pyplot.hist¶
# ](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html)

# %%
n=1000
x = np.random.choice([0, 1], size=n, p=[0.6, 0.4])
p_head = (x==1).sum()/len(x)
p_tail = (x==0).sum()/len(x)
print(f"p(head) ={p_head}")
print(f"p(tail) ={p_tail}")
plt.hist(x);
# Out:
# p(head) =0.405
# p(tail) =0.595

# %%
#type your code here:

# %% [markdown]
# # Problem 3: Independence
#
# Use NumPy to create simulations and compute **empirical  probability** for the following outcomes. Compare the results with the **theoretical probability**.
#
# 1. Two fair coin flips produce exactly two heads

# %%
n=1_000_000
x = np.random.choice([0, 1], size=(n,2))
sum = x.sum(axis=1)
print(f"sum={sum}")
p = (sum==2).sum()/n
print(f"p(two heads) ={p}")
# Out:
# sum=[0 2 0 ... 0 1 0]
# p(two heads) =0.24976

# %%
#type your code here:

# simulate 1 million tests of two fair coin flips


# sums of all tests


# proportion of tests that produced exactly two heads
# Out:
# 0.249809

# %% [markdown]
# 2. Three fair coin flips produce exactly one head

# %%
n=1_000_000
x = np.random.choice([0, 1], size=(n,3))
sum = x.sum(axis=1)
print(f"sum={sum}")
p = (sum==1).sum()/n
print(f"p(one head only) ={p}")
# Out:
# sum=[0 1 2 ... 1 1 2]
# p(one head only) =0.376117

# %%
#type your code here:

# simulate 1 million tests of three fair coin flips


# sums of all tests


# proportion of tests that produced exactly one head
# Out:
# 0.374819

# %% [markdown]
# 3. Three biased coin flips with P(H) = 0.6 produce exactly one head

# %%
n=1_000_000
x = np.random.choice([0, 1], size=(n,3), p=[0.4, 0.6])
sum = x.sum(axis=1)
print(f"sum={sum}")
p = (sum==1).sum()/n
print(f"p(one head only) ={p}")
# Out:
# sum=[1 2 2 ... 2 2 2]
# p(one head only) =0.288117

# %%
#type your code here:


# simulate 1 million tests of three biased coin flips
# hint: use np.random.choice()


# sums of all tests


# proportion of tests that produced exactly one head
# Out:
# 0.288288

# %% [markdown]
# # Problem 4:Random Variables Statistical Tools
# Simulate Rolling a fair die $1000$ times. Then calculate the following:
#
# - Sample mean
# - Sample variance
# - Sample standard deviation
#
# Compare the results with the theoretical probability.

# %%
n=1000
x = np.random.choice([1,2,3,4,5,6], size=n)
sample_mean=np.mean(x)
print(f"sample mean ={sample_mean}")
sample_var=np.var(x)
print(f"sample variance ={sample_var}")
sample_std=np.std(x)
print(f"sample standard deviation ={sample_std}")
# Out:
# sample mean =3.42
# sample variance =2.9836
# sample standard deviation =1.7273100474437124

# %%
#type your code here:
# Out:
# Sample mean: 3.463
# Sample variance: 3.005636636636637
# Sample standard deviation: 1.7336772008181445
# 3.463
# 3.005636636636637
# 1.7336772008181445

# %% [markdown]
# # Problem 5: Correlation and Covariance
#
# The CSV file includes a hourly/daily summary for Szeged, Hungary area, between 2006 and 2016. After inspecting the data:
#
# - Calculate the covariance and correlation coeffecient between temperature and apparent temperature
# - Calculate the covariance and correlation coeffecient between temperature and humidity

# %%
df = pd.read_csv('/content/weatherHistory.csv')
temperature = df['Temperature (C)'].to_numpy().reshape(-1, 1)
apparant_temp = df['Apparent Temperature (C)'].to_numpy().reshape(-1, 1)
humidity = df['Humidity'].to_numpy().reshape(-1, 1)

# %%
plt.scatter(temperature, apparant_temp)
plt.grid()
plt.xlabel('Temperature (C)')
plt.ylabel('Apparent Temperature (C)')
# Out:
# Text(0, 0.5, 'Apparent Temperature (C)')

# %%
plt.scatter(humidity, temperature)
plt.grid()
plt.xlabel('Humidity')
plt.ylabel('Temperature (C)')
# Out:
# Text(0, 0.5, 'Temperature (C)')

# %% [markdown]
# ## Temperature and Apparent Temperature

# %%
cov= np.cov(df['Temperature (C)'],df['Apparent Temperature (C)'])
covariance = cov[0, 1]
print(f"covariance ={covariance}")
print(f"np.covariance ={cov}")

corr = np.corrcoef(df['Temperature (C)'],df['Apparent Temperature (C)'])
correlation= corr[0, 1]
print(f"correlation ={correlation}")
print(f"np.correlation ={corr}")
# Out:
# covariance =101.41828318854088
# np.covariance =[[ 91.23203712 101.41828319]
#  [101.41828319 114.42254413]]
# correlation =0.9926285641920792
# np.correlation =[[1.         0.99262856]
#  [0.99262856 1.        ]]

# %%
#type your code here:
# Out:
# Covariance:  [[101.41828319]]
# ---------------------------------------------------
# np.cov():
#  [[ 91.23203712 101.41828319]
#  [101.41828319 114.42254413]]
# ---------------------------------------------------
# Correlation Cof:  [[0.99262856]]
# ---------------------------------------------------
# np.corrcoef():
#  [[1.         0.99262856]
#  [0.99262856 1.        ]]

# %% [markdown]
# ## Temperature and Humidity

# %%
cov= np.cov(df['Temperature (C)'],df['Humidity'])
covariance = cov[0, 1]
print(f"covariance ={covariance}")
print(f"np.covariance ={cov}")

corr = np.corrcoef(df['Temperature (C)'],df['Humidity'])
correlation= corr[0, 1]
print(f"correlation ={correlation}")
print(f"np.correlation ={corr}")
# Out:
# covariance =-1.180461789785136
# np.covariance =[[ 9.12320371e+01 -1.18046179e+00]
#  [-1.18046179e+00  3.82095917e-02]]
# correlation =-0.6322546750264317
# np.correlation =[[ 1.         -0.63225468]
#  [-0.63225468  1.        ]]

# %%
#type your code here:
# Out:
# Covariance:  [[-1.18046179]]
# ---------------------------------------------------
# np.cov():
#  [[ 9.12320371e+01 -1.18046179e+00]
#  [-1.18046179e+00  3.82095917e-02]]
# ---------------------------------------------------
# Correlation Cof:  [[-0.63225468]]
# ---------------------------------------------------
# np.corrcoef():
#  [[ 1.         -0.63225468]
#  [-0.63225468  1.        ]]
